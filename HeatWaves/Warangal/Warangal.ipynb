# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
pd.options.display.float_format = '{:.2f}'.format

import pickle
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt
from itertools import combinations
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
import pandas as pd
df = pd.read_csv("Warangal.csv")
df ['dates'] = pd.to_datetime(df ['date'])
df=df.set_index(['date'])
df=df.sort_index()
df
# Out:
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# ...
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '13-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '14-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '15-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '16-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '17-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '18-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '19-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '20-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '21-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '22-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '23-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '24-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '25-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '26-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '27-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '28-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '29-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '30-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/461794695.py:3: UserWarning: Parsing '31-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df ['dates'] = pd.to_datetime(df ['date'])
#             district  temp      dates
# date
# 01-01-2019  Warangal 26.40 2019-01-01
# 01-01-2020  Warangal 27.00 2020-01-01
# 01-01-2021  Warangal 30.30 2021-01-01
# 01-01-2022  Warangal 29.20 2022-01-01
# 01-02-2019  Warangal 30.30 2019-01-02
# ...              ...   ...        ...
# 31-10-2020  Warangal 33.50 2020-10-31
# 31-10-2021  Warangal 33.90 2021-10-31
# 31-12-2019  Warangal 29.20 2019-12-31
# 31-12-2020  Warangal 29.90 2020-12-31
# 31-12-2021  Warangal 28.80 2021-12-31
#
# [1306 rows x 3 columns]

# %%
target= df[['dates', 'temp']] 
target.dropna(inplace=True)
target.columns = ['ds', 'y'] 
target.drop_duplicates(inplace=True)
target
# Out:
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/1535585159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target.dropna(inplace=True)
#
# WARNING - (py.warnings._showwarnmsg) - /var/folders/bm/xy68m44x3nl6g2dq4wbnmh4c0000gn/T/ipykernel_57685/1535585159.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target.drop_duplicates(inplace=True)
#                    ds     y
# date
# 01-01-2019 2019-01-01 26.40
# 01-01-2020 2020-01-01 27.00
# 01-01-2021 2021-01-01 30.30
# 01-01-2022 2022-01-01 29.20
# 01-02-2019 2019-01-02 30.30
# ...               ...   ...
# 31-10-2020 2020-10-31 33.50
# 31-10-2021 2021-10-31 33.90
# 31-12-2019 2019-12-31 29.20
# 31-12-2020 2020-12-31 29.90
# 31-12-2021 2021-12-31 28.80
#
# [1306 rows x 2 columns]

# %%
# from sklearn.model_selection import train_test_split
# tr,ts=train_test_split(target,train_size=0.3)
tr=target[:'2022']
ts=target['2022':]

# %%
NP = NeuralProphet()
model = NP.fit(tr, freq='D', epochs=1000)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 91.529% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# WARNING - (py.warnings._showwarnmsg) - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1789: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
#
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (54) is too small than the required number for the learning rate finder (224). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/224 [00:00<?, ?it/s]
# Missing logger folder: /Users/MUKESHTP/Desktop/HeatWaves/Warangal/lightning_logs
# Training: 0it [00:00, ?it/s]

# %%
future = NP.make_future_dataframe(ts, periods=len(ts))
forecast = NP.predict(future)
forecast
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency Y corresponds to 70.175% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency D is different than major frequency Y
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.781% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.781% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 54it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#             ds     y  yhat1  trend  season_yearly  season_weekly
# 0   2022-10-01  None  33.29  33.54          -0.44           0.19
# 1   2022-10-02  None  33.29  33.54          -0.44           0.20
# 2   2022-10-03  None  32.78  33.54          -0.45          -0.32
# 3   2022-10-04  None  33.24  33.54          -0.45           0.15
# 4   2022-10-05  None  33.17  33.54          -0.46           0.09
# ..         ...   ...    ...    ...            ...            ...
# 451 2023-12-26  None  31.17  33.27          -2.25           0.15
# 452 2023-12-27  None  31.08  33.27          -2.27           0.09
# 453 2023-12-28  None  30.75  33.27          -2.29          -0.23
# 454 2023-12-29  None  30.88  33.27          -2.30          -0.08
# 455 2023-12-30  None  31.15  33.27          -2.31           0.19
#
# [456 rows x 6 columns]

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,r2_score,mean_absolute_error
print("Mean absolute percentage error: ",mean_absolute_percentage_error(forecast['yhat1'],ts['y']))
print("Mean Squared Error: ",mean_squared_error(forecast['yhat1'],ts['y']))
print("Mean Absolute Error: ",mean_absolute_error(forecast['yhat1'],ts['y']))
# Out:
# Mean absolute percentage error:  0.10166244619940029
# Mean Squared Error:  18.302027623742937
# Mean Absolute Error:  3.360353910713865

# %%
NP = NeuralProphet()
model = NP.fit(target, freq='D', epochs=1000)
future = NP.make_future_dataframe(target, periods=370)
forecast = NP.predict(future)
forecast
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.552% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (py.warnings._showwarnmsg) - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1789: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
#
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (42) is too small than the required number for the learning rate finder (228). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/228 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.552% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.73% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.73% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 42it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#             ds     y  yhat1  trend  season_yearly  season_weekly
# 0   2023-01-01  None  33.35  36.50          -3.18           0.03
# 1   2023-01-02  None  33.43  36.50          -3.18           0.12
# 2   2023-01-03  None  33.31  36.50          -3.18          -0.01
# 3   2023-01-04  None  33.40  36.50          -3.18           0.07
# 4   2023-01-05  None  33.40  36.50          -3.17           0.07
# ..         ...   ...    ...    ...            ...            ...
# 365 2024-01-01  None  33.32  36.38          -3.18           0.12
# 366 2024-01-02  None  33.19  36.38          -3.18          -0.01
# 367 2024-01-03  None  33.27  36.38          -3.18           0.07
# 368 2024-01-04  None  33.27  36.38          -3.18           0.07
# 369 2024-01-05  None  33.13  36.38          -3.17          -0.08
#
# [370 rows x 6 columns]

# %%
data= forecast[['ds', 'yhat1']].iloc[:365,:]
data.dropna(inplace=True)
data.columns = ['date', 'Temp'] 
data
# Out:
#           date  Temp
# 0   2023-01-01 33.35
# 1   2023-01-02 33.43
# 2   2023-01-03 33.31
# 3   2023-01-04 33.40
# 4   2023-01-05 33.40
# ..         ...   ...
# 360 2023-12-27 33.33
# 361 2023-12-28 33.30
# 362 2023-12-29 33.15
# 363 2023-12-30 33.02
# 364 2023-12-31 33.24
#
# [365 rows x 2 columns]

# %%
avg=target['y'].mean()
print(avg)
print(max(target['y']))
# Out:
# 36.38990034875934
# 46.305

# %%
loc=[]
for i in data['Temp']:
    if i-avg>=4.5 and i-avg<=6.4:
        loc.append('Heatwave')
    elif i-avg>=6.5:
        loc.append('Severe Heatwave')
    else:
        loc.append('No Heatwave')

# %%
data['Class']=loc

# %%
data
# Out:
#           date  Temp        Class
# 0   2023-01-01 33.35  No Heatwave
# 1   2023-01-02 33.43  No Heatwave
# 2   2023-01-03 33.31  No Heatwave
# 3   2023-01-04 33.40  No Heatwave
# 4   2023-01-05 33.40  No Heatwave
# ..         ...   ...          ...
# 360 2023-12-27 33.33  No Heatwave
# 361 2023-12-28 33.30  No Heatwave
# 362 2023-12-29 33.15  No Heatwave
# 363 2023-12-30 33.02  No Heatwave
# 364 2023-12-31 33.24  No Heatwave
#
# [365 rows x 3 columns]

# %%
data.to_csv('Warangal2023.csv')
